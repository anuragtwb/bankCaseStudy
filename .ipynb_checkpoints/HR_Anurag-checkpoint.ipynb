# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

# %%
df = pd.DataFrame(pd.read_excel("HRDataset_v9.xlsx"))

# %%
df.head()
# Out:
#           Employee Name  Employee Number  MarriedID  MaritalStatusID  \
# 0            Brown, Mia       1103024456          1                1
# 1  LaRotonda, William         1106026572          0                2
# 2      Steans, Tyrone         1302053333          0                0
# 3       Howard, Estelle       1211050782          1                1
# 4           Singh, Nan        1307059817          0                0
#
#    GenderID  EmpStatus_ID  DeptID  Perf_ScoreID  Age  Pay Rate  ...  \
# 0         0             1       1             3   30     28.50  ...
# 1         1             1       1             3   34     23.00  ...
# 2         1             1       1             3   31     29.00  ...
# 3         0             1       1             9   32     21.50  ...
# 4         0             1       1             9   30     16.56  ...
#
#           Date of Hire  Days Employed Date of Termination  \
# 0           10/27/2008           3317                 NaN
# 1  2014-06-01 00:00:00           1420                 NaN
# 2            9/29/2014           1154                 NaN
# 3            2/16/2015             58           4/15/2015
# 4  2015-01-05 00:00:00            940                 NaN
#
#         Reason For Term Employment Status     Department  \
# 0  N/A - still employed            Active  Admin Offices
# 1  N/A - still employed            Active  Admin Offices
# 2  N/A - still employed            Active  Admin Offices
# 3  N/A - still employed            Active  Admin Offices
# 4  N/A - still employed            Active  Admin Offices
#
#                    Position        Manager Name         Employee Source  \
# 0              Accountant I  Brandon R. LeBlanc      Diversity Job Fair
# 1              Accountant I  Brandon R. LeBlanc      Website Banner Ads
# 2              Accountant I  Brandon R. LeBlanc         Internet Search
# 3  Administrative Assistant  Brandon R. LeBlanc  Pay Per Click - Google
# 4  Administrative Assistant  Brandon R. LeBlanc      Website Banner Ads
#
#           Performance Score
# 0               Fully Meets
# 1               Fully Meets
# 2               Fully Meets
# 3  N/A- too early to review
# 4  N/A- too early to review
#
# [5 rows x 28 columns]

# %%
df.describe()
# Out:
#        Employee Number   MarriedID  MaritalStatusID    GenderID  EmpStatus_ID  \
# count     3.100000e+02  310.000000       310.000000  310.000000    310.000000
# mean      1.199745e+09    0.396774         0.809677    0.429032      2.396774
# std       1.829600e+08    0.490019         0.944702    0.495738      1.795533
# min       6.020003e+08    0.000000         0.000000    0.000000      1.000000
# 25%       1.101024e+09    0.000000         0.000000    0.000000      1.000000
# 50%       1.203032e+09    0.000000         1.000000    0.000000      1.000000
# 75%       1.378814e+09    1.000000         1.000000    1.000000      5.000000
# max       1.988300e+09    1.000000         4.000000    1.000000      5.000000
#
#            DeptID  Perf_ScoreID         Age    Pay Rate           Zip  \
# count  310.000000    310.000000  310.000000  310.000000    310.000000
# mean     4.606452      3.458065   38.867742   31.284806   6569.732258
# std      1.082349      2.318460    8.922459   15.383615  16933.864054
# min      1.000000      0.000000   25.000000   14.000000   1013.000000
# 25%      5.000000      3.000000   32.000000   20.000000   1901.250000
# 50%      5.000000      3.000000   37.000000   24.000000   2132.000000
# 75%      5.000000      3.000000   44.000000   45.315000   2357.000000
# max      6.000000      9.000000   67.000000   80.000000  98052.000000
#
#        Days Employed
# count     310.000000
# mean     1296.080645
# std       769.491382
# min         2.000000
# 25%       766.250000
# 50%      1238.000000
# 75%      1732.750000
# max      4339.000000

# %%
df.shape
# Out:
# (310, 28)

# %%
df.columns
# Out:
# Index(['Employee Name', 'Employee Number', 'MarriedID', 'MaritalStatusID',
#        'GenderID', 'EmpStatus_ID', 'DeptID', 'Perf_ScoreID', 'Age', 'Pay Rate',
#        'State', 'Zip', 'DOB', 'Sex', 'MaritalDesc', 'CitizenDesc',
#        'Hispanic/Latino', 'RaceDesc', 'Date of Hire', 'Days Employed',
#        'Date of Termination', 'Reason For Term', 'Employment Status',
#        'Department', 'Position', 'Manager Name', 'Employee Source',
#        'Performance Score'],
#       dtype='object')

# %%
df['Sex']
# Out:
# 0      Female
# 1        Male
# 2        Male
# 3      Female
# 4      Female
#         ...
# 305      Male
# 306      Male
# 307      Male
# 308      Male
# 309      Male
# Name: Sex, Length: 310, dtype: object

# %%
df['Sex'].unique()
# Out:
# array(['Female', 'Male'], dtype=object)

# %%
df['Sex'].value_counts() 
df['Sex'].value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
df['Sex'].value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
# Gender diversity across departmets
import seaborn as sns
plt.figure(figsize=(16,9))
ax=sns.countplot(x=df['Department'],hue=df['Sex'])

# %% [markdown]
# **Conclusions from graph :**
#
# No males in executive office and no females in software engineering department. Gender diversity is not maintained in production department and software engineering.(No.of females is nearly double the number of males)

# %%
df['RaceDesc'].value_counts().plot(kind='pie')
# Out:
# <AxesSubplot:ylabel='RaceDesc'>

# %%
df['CitizenDesc'].unique()
# Out:
# array(['US Citizen', 'Eligible NonCitizen', 'Non-Citizen'], dtype=object)

# %%
df['CitizenDesc'].value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
df['Age'].hist(bins=40)
# Out:
# <AxesSubplot:>

# %%
df['Position'].unique()
# Out:
# array(['Accountant I', 'Administrative Assistant',
#        'Shared Services Manager', 'Sr. Accountant', 'President & CEO',
#        'CIO', 'Database Administrator', 'IT Director', 'IT Manager - DB',
#        'IT Manager - Infra', 'IT Manager - Support', 'IT Support',
#        'Network Engineer', 'Sr. DBA', 'Sr. Network Engineer',
#        'Director of Operations', 'Production Manager',
#        'Production Technician I', 'Production Technician II',
#        'Area Sales Manager', 'Director of Sales', 'Sales Manager',
#        'Software Engineer', 'Software Engineering Manager', 'BI Director',
#        'Senior BI Developer', 'BI Developer', 'Data Architect'],
#       dtype=object)

# %%
plt.figure(figsize=(16,9))
df['Position'].value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %% [markdown]
# **Is there any relationship between pay rate and age?**

# %%
df['Pay Rate'].describe()
# Out:
# count    310.000000
# mean      31.284806
# std       15.383615
# min       14.000000
# 25%       20.000000
# 50%       24.000000
# 75%       45.315000
# max       80.000000
# Name: Pay Rate, dtype: float64

# %%
df['Age'].describe()
# Out:
# count    310.000000
# mean      38.867742
# std        8.922459
# min       25.000000
# 25%       32.000000
# 50%       37.000000
# 75%       44.000000
# max       67.000000
# Name: Age, dtype: float64

# %%
df.plot(x='Age',y='Pay Rate',kind='scatter')
# Looks like thery are not related!
# Out:
# <AxesSubplot:xlabel='Age', ylabel='Pay Rate'>

# %% [markdown]
# **Which manager has the best performers?**

# %%
df['Manager Name'].unique()
# Out:
# array(['Brandon R. LeBlanc', 'Janet King', 'Board of Directors',
#        'Simon Roup', 'Jennifer Zamora', 'Eric Dougall', 'Peter Monroe',
#        'Michael Albert', 'Elijiah Gray', 'Webster Butler', 'Amy Dunn',
#        'Ketsia Liebig', 'Brannon Miller', 'David Stanley',
#        'Kissy Sullivan', 'Kelley Spirea', 'Lynn Daneault', 'John Smith',
#        'Debra Houlihan', 'Alex Sweetwater', 'Brian Champaigne'],
#       dtype=object)

# %%
df['Performance Score']
# Out:
# 0                   Fully Meets
# 1                   Fully Meets
# 2                   Fully Meets
# 3      N/A- too early to review
# 4      N/A- too early to review
#                  ...
# 305                 Fully Meets
# 306                 Fully Meets
# 307                 Fully Meets
# 308                 Fully Meets
# 309                 Fully Meets
# Name: Performance Score, Length: 310, dtype: object

# %%
plt.figure(figsize=(20,20))
sns.countplot(y=df['Manager Name'], hue=df['Performance Score'])
# Out:
# <AxesSubplot:xlabel='count', ylabel='Manager Name'>

# %% [markdown]
# **Davind Stanley and Kelly Spirea have highest number of employees who fully meet the expectation.**
#
# **Simon and Brannon have a highest number of exceptional employess!**
#
# **Employees working with Michael need to improve their performance.**

# %% [markdown]
# **Which department pays more?**

# %%
df.groupby('Department')['Pay Rate'].sum().plot(kind='bar')
#Production department pays more!
# Out:
# <AxesSubplot:xlabel='Department'>

# %% [markdown]
# Which position gives away more money? This doesn't mean that all employees in this position get maximum pay. The number of employees could be more for this dept. Note that we are taking sum of pay rate for each department.

# %%
plt.figure(figsize=(16,9))
df.groupby('Position')['Pay Rate'].sum().plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='Position'>

# %% [markdown]
# Who gets the highest salary ?

# %%
id_of_person_with_highgest_pay = df['Pay Rate'].idxmax()
df.loc[id_of_person_with_highgest_pay]


df.loc[df['Pay Rate'].idxmax()]
# Out:
# Employee Name                     King, Janet
# Employee Number                    1001495124
# MarriedID                                   1
# MaritalStatusID                             1
# GenderID                                    0
# EmpStatus_ID                                1
# DeptID                                      2
# Perf_ScoreID                                3
# Age                                        63
# Pay Rate                                   80
# State                                      MA
# Zip                                      1902
# DOB                                 9/21/1954
# Sex                                    Female
# MaritalDesc                           Married
# CitizenDesc                        US Citizen
# Hispanic/Latino                           Yes
# RaceDesc                                White
# Date of Hire              2012-02-07 00:00:00
# Days Employed                            1973
# Date of Termination                       NaN
# Reason For Term          N/A - still employed
# Employment Status                      Active
# Department                   Executive Office
# Position                      President & CEO
# Manager Name               Board of Directors
# Employee Source        Pay Per Click - Google
# Performance Score                 Fully Meets
# Name: 10, dtype: object

# %%
plt.figure(figsize=(16,16))
sns.heatmap(df.corr(),annot=True)
# Out:
# <AxesSubplot:>

# %%
HispLat_map ={'No': 0, 'Yes': 1, 'no': 0, 'yes': 1}
df['Hispanic/Latino'] = df['Hispanic/Latino'].replace(HispLat_map)
df['Hispanic/Latino']
# Out:
# 0      0
# 1      0
# 2      0
# 3      0
# 4      0
#       ..
# 305    0
# 306    0
# 307    0
# 308    0
# 309    0
# Name: Hispanic/Latino, Length: 310, dtype: int64

# %%
#Exploring null values in the dataset, there seems to be quite a few
df.isnull().sum()
# Out:
# Employee Name            0
# Employee Number          0
# MarriedID                0
# MaritalStatusID          0
# GenderID                 0
# EmpStatus_ID             0
# DeptID                   0
# Perf_ScoreID             0
# Age                      0
# Pay Rate                 0
# State                    0
# Zip                      0
# DOB                      0
# Sex                      0
# MaritalDesc              0
# CitizenDesc              0
# Hispanic/Latino          0
# RaceDesc                 0
# Date of Hire             0
# Days Employed            0
# Date of Termination    207
# Reason For Term          0
# Employment Status        0
# Department               0
# Position                 0
# Manager Name             0
# Employee Source          0
# Performance Score        0
# dtype: int64

# %% [markdown]
# ## Missing data
#
# There are 3 features with more than 30% of missing data.

# %%
#Dropping null values
df.dropna(how='all', inplace=True)

# %%
df = df.loc[:, (df.isnull().sum()/df.shape[0] < 0.3)]

# %%
df.isnull().sum()
# Out:
# Employee Name        0
# Employee Number      0
# MarriedID            0
# MaritalStatusID      0
# GenderID             0
# EmpStatus_ID         0
# DeptID               0
# Perf_ScoreID         0
# Age                  0
# Pay Rate             0
# State                0
# Zip                  0
# DOB                  0
# Sex                  0
# MaritalDesc          0
# CitizenDesc          0
# Hispanic/Latino      0
# RaceDesc             0
# Date of Hire         0
# Days Employed        0
# Reason For Term      0
# Employment Status    0
# Department           0
# Position             0
# Manager Name         0
# Employee Source      0
# Performance Score    0
# dtype: int64

# %%
df.isnull().sum()/df.shape[0]
# Out:
# Employee Name        0.0
# Employee Number      0.0
# MarriedID            0.0
# MaritalStatusID      0.0
# GenderID             0.0
# EmpStatus_ID         0.0
# DeptID               0.0
# Perf_ScoreID         0.0
# Age                  0.0
# Pay Rate             0.0
# State                0.0
# Zip                  0.0
# DOB                  0.0
# Sex                  0.0
# MaritalDesc          0.0
# CitizenDesc          0.0
# Hispanic/Latino      0.0
# RaceDesc             0.0
# Date of Hire         0.0
# Days Employed        0.0
# Reason For Term      0.0
# Employment Status    0.0
# Department           0.0
# Position             0.0
# Manager Name         0.0
# Employee Source      0.0
# Performance Score    0.0
# dtype: float64

# %% [markdown]
# ## General Informations
#
# First, I will clean the data to improve the classifier's performance.
#
# Next, I'll do a Bayesian optimization on Random Forest's hyper parameters. For that, I will use the scikit-optmize package.
#
# And, I will end with the results of the optimized classifier.

# %%
pip install scikit-optimize
# Out:
# Collecting scikit-optimize
#   Downloading scikit_optimize-0.8.1-py2.py3-none-any.whl (101 kB)
# Requirement already satisfied: scipy>=0.19.1 in c:\users\deepak\anaconda3\lib\site-packages (from scikit-optimize) (1.5.2)
# Requirement already satisfied: joblib>=0.11 in c:\users\deepak\anaconda3\lib\site-packages (from scikit-optimize) (0.17.0)
# Requirement already satisfied: numpy>=1.13.3 in c:\users\deepak\anaconda3\lib\site-packages (from scikit-optimize) (1.19.2)
# Requirement already satisfied: scikit-learn>=0.20.0 in c:\users\deepak\anaconda3\lib\site-packages (from scikit-optimize) (0.24.1)
# Collecting pyaml>=16.9
#   Downloading pyaml-20.4.0-py2.py3-none-any.whl (17 kB)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\deepak\anaconda3\lib\site-packages (from scikit-learn>=0.20.0->scikit-optimize) (2.1.0)
# Requirement already satisfied: PyYAML in c:\users\deepak\anaconda3\lib\site-packages (from pyaml>=16.9->scikit-optimize) (5.3.1)
# Installing collected packages: pyaml, scikit-optimize
# Successfully installed pyaml-20.4.0 scikit-optimize-0.8.1
# Note: you may need to restart the kernel to use updated packages.

# %%
from sklearn.preprocessing import OneHotEncoder
from sklearn.compose import ColumnTransformer
from sklearn.model_selection import (train_test_split, ShuffleSplit, cross_val_score)
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import plot_confusion_matrix

from skopt.space import (Real,
                         Integer,
                         Categorical)
from skopt.utils import use_named_args
from skopt import (gp_minimize, 
                   dump, 
                   load)
from skopt.plots import plot_convergence
from skopt.callbacks import CheckpointSaver

import json

# %%
df[df.isnull().any(axis=1)]
# Out:
# Empty DataFrame
# Columns: [Employee Name, Employee Number, MarriedID, MaritalStatusID, GenderID, EmpStatus_ID, DeptID, Perf_ScoreID, Age, Pay Rate, State, Zip, DOB, Sex, MaritalDesc, CitizenDesc, Hispanic/Latino, RaceDesc, Date of Hire, Days Employed, Reason For Term, Employment Status, Department, Position, Manager Name, Employee Source, Performance Score]
# Index: []
#
# [0 rows x 27 columns]

# %%
df.dtypes
# Out:
# Employee Name         object
# Employee Number        int64
# MarriedID              int64
# MaritalStatusID        int64
# GenderID               int64
# EmpStatus_ID           int64
# DeptID                 int64
# Perf_ScoreID           int64
# Age                    int64
# Pay Rate             float64
# State                 object
# Zip                    int64
# DOB                   object
# Sex                   object
# MaritalDesc           object
# CitizenDesc           object
# Hispanic/Latino        int64
# RaceDesc              object
# Date of Hire          object
# Days Employed          int64
# Reason For Term       object
# Employment Status     object
# Department            object
# Position              object
# Manager Name          object
# Employee Source       object
# Performance Score     object
# dtype: object
